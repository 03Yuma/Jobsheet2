# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

data = "wbc.csv"
df = pd.read_csv(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#memisahkan variabel yang digunakan dan tidak digunakan

used_columns = ['id','diagnosis','radius_mean','area_mean']
df_used = df[used_columns]

unused_columns =df.columns.difference(used_columns)
df_unused = df[unused_columns]

# %%
df_used.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           569 non-null    int64
#  1   diagnosis    569 non-null    object
#  2   radius_mean  569 non-null    float64
#  3   area_mean    569 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 17.9+ KB

# %%
df_unused.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 32              0 non-null      float64
#  1   area_se                  569 non-null    float64
#  2   area_worst               569 non-null    float64
#  3   compactness_mean         569 non-null    float64
#  4   compactness_se           569 non-null    float64
#  5   compactness_worst        569 non-null    float64
#  6   concave points_mean      569 non-null    float64
#  7   concave points_se        569 non-null    float64
#  8   concave points_worst     569 non-null    float64
#  9   concavity_mean           569 non-null    float64
#  10  concavity_se             569 non-null    float64
#  11  concavity_worst          569 non-null    float64
#  12  fractal_dimension_mean   569 non-null    float64
# ...

# %%
#melakuakn encoding pada kolom diagnosis

new = LabelEncoder()
df_used['diagnosis']=new.fit_transform(df_used['diagnosis'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7660\2239249315.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_used['diagnosis']=new.fit_transform(df_used['diagnosis'])

# %%
df_used.head()
# Out:
#          id  diagnosis  radius_mean  area_mean
# 0    842302          1        17.99     1001.0
# 1    842517          1        20.57     1326.0
# 2  84300903          1        19.69     1203.0
# 3  84348301          1        11.42      386.1
# 4  84358402          1        20.29     1297.0

# %%
#melakukan standarisasi data

features = df.select_dtypes(include=['float','int64','int32'])
standar =StandardScaler()

df_scaled = df.copy()

df_scaled[features.columns] = standar.fit_transform(features)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
df_scaled.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0 -0.236405   1.297676     1.097064     -2.073335        1.269934   0.984375
# 1 -0.236403   1.297676     1.829821     -0.353632        1.685955   1.908708
# 2  0.431741   1.297676     1.579888      0.456187        1.566503   1.558884
# 3  0.432121   1.297676    -0.768909      0.253732       -0.592687  -0.764464
# 4  0.432201   1.297676     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
# ...

# %%
#melakukan split data

from sklearn.model_selection import train_test_split

# Stratified split dengan rasio 80:20, tetap menggunakan DataFrame 'df' langsung
df_train, df_test = train_test_split(df, test_size=0.2, random_state=0, stratify=df['diagnosis'])

# Menampilkan ukuran data setelah split
print(f'Jumlah data asli: {df.shape[0]}')
print(f'Jumlah data train: {df_train.shape[0]}')
print(f'Jumlah data test: {df_test.shape[0]}')
# Out:
# Jumlah data asli: 569
# Jumlah data train: 455
# Jumlah data test: 114
